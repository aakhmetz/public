# %%
from sympy import *
init_printing(use_latex='mathjax')

# %%
a, λ, δ, γ = symbols('a, λ, δ, γ')
x = Function('x')(a)
y = Function('y')(a)
z = Function('z')(a)
sol = dsolve([x.diff()+λ*x-δ*z, y.diff()+γ*y-λ*x, z.diff()+δ*z-γ*y])
sol
# Out:
# ⎡                        ⎛                 ___________________________________
# ⎢                        ⎜                ╱  2                    2
# ⎢                        ⎜  γ   δ   λ   ╲╱  γ  - 2⋅γ⋅δ - 2⋅γ⋅λ + δ  - 2⋅δ⋅λ +
# ⎢                      a⋅⎜- ─ - ─ - ─ - ──────────────────────────────────────
# ⎢                        ⎝  2   2   2                       2
# ⎢       C₁⋅δ   2⋅C₂⋅δ⋅ℯ
# ⎢x(a) = ──── - ───────────────────────────────────────────────────────────────
# ⎢        λ                           ______________________________________
# ⎢                                   ╱  2                    2            2
# ⎣                     γ + δ - λ + ╲╱  γ  - 2⋅γ⋅δ - 2⋅γ⋅λ + δ  - 2⋅δ⋅λ + λ
#
# ___⎞             ⎛                 ______________________________________⎞
#  2 ⎟             ⎜                ╱  2                    2            2 ⎟
# λ  ⎟             ⎜  γ   δ   λ   ╲╱  γ  - 2⋅γ⋅δ - 2⋅γ⋅λ + δ  - 2⋅δ⋅λ + λ  ⎟
# ...
